# %% [markdown]
# ## 📊 Bar Chart Visualization
# A bar chart is used to represent categorical data using rectangular bars. The length or height of each bar reflects the magnitude of the value associated with that category. This type of chart is ideal for comparing quantities across discrete groups.
#
# In this example, you will create a bar chart to display the number of products sold by different store locations, using data from a sales_data DataFrame. The DataFrame has store names as the index and a column named "Total_Sales" that holds the number of products sold at each location.

# %%
import matplotlib.pyplot as plt
import pandas as pd

medals = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\KaranCodes\Goal-to-be-ML-Engineer-2026\Data-wrangling-and-visualization-python\Data-VIsualization\Matplotlib\dataset\olympics_medals_2018.csv', index_col=0)

fig, ax = plt.subplots()

# Plot a bar-chart of gold medals as a function of country
ax.bar(medals.index, medals['Gold'])

# Set the x-axis tick labels to the country names
ax.set_xticklabels(medals.index, rotation=90)

# Set the y-axis label
ax.set_ylabel('Number of medals')

plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_31988\408097997.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(medals.index, rotation=90)

# %% [markdown]
# ## 📊 Stacked Bar Chart
# A stacked bar chart is useful when you want to visualize the composition of multiple sub-categories within a main category. Instead of placing bars side by side, each component is stacked vertically (or horizontally), allowing you to see both the total and the individual contributions of each variable.

# %%
fig, ax = plt.subplots()

# Add bars for "Gold" with the label "Gold"
ax.bar(medals.index, medals['Gold'], label="Gold")

# Stack bars for "Silver" on top with label "Silver"
ax.bar(medals.index, medals['Silver'], bottom=medals['Gold'], label="Silver")

# Stack bars for "Bronze" on top of that with label "Bronze"
ax.bar(medals.index, medals['Bronze'], bottom=medals['Gold'] + medals['Silver'], label="Bronze")

ax.set_xticklabels(medals.index, rotation=90)
# Display the legend
ax.legend()

plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_31988\1308352430.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(medals.index, rotation=90)

# %% [markdown]
# ## 📊 Creating Histograms
# A histogram is a powerful tool for visualizing the distribution of a numeric variable. It groups values into bins and shows how many data points fall into each bin, giving insights into the shape, spread, and center of the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(42)

# Computer Science students' scores
cs_scores = np.random.normal(loc=78, scale=10, size=100)
cs_students = pd.DataFrame({'Final_Score': np.clip(cs_scores, 0, 100)})

# Mechanical Engineering students' scores
me_scores = np.random.normal(loc=72, scale=12, size=100)
me_students = pd.DataFrame({'Final_Score': np.clip(me_scores, 0, 100)})

# Plotting
fig, ax = plt.subplots()

# Plot histogram of final exam scores for Computer Science students
ax.hist(cs_students['Final_Score'], alpha=0.7, label='Computer Science')

# Compare with histogram of final exam scores for Mechanical Engineering students
ax.hist(me_students['Final_Score'], alpha=0.7, label='Mechanical Engineering')

# Set x-axis label
ax.set_xlabel("Final Exam Score")

# Set y-axis label
ax.set_ylabel("Number of Students")

# Add a legend
ax.legend()

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create synthetic data
np.random.seed(42)

# Simulated weights for men's rowing (typically heavier)
mens_rowing = pd.DataFrame({
    'Weight': np.random.normal(loc=90, scale=5, size=100)  # Mean ~90kg
})

# Simulated weights for men's gymnastics (typically lighter)
mens_gymnastics = pd.DataFrame({
    'Weight': np.random.normal(loc=68, scale=4, size=100)  # Mean ~68kg
})

# Plotting
fig, ax = plt.subplots()

# Plot a histogram of "Weight" for men's rowing
ax.hist(mens_rowing['Weight'], histtype='step', bins=5, label="Rowing")

# Plot a histogram of "Weight" for men's gymnastics
ax.hist(mens_gymnastics['Weight'], histtype='step', bins=5, label="Gymnastics")

# Labels and legend
ax.set_xlabel("Weight (kg)")
ax.set_ylabel("# of observations")
ax.legend()

plt.show()

# %% [markdown]
# ## 📊 Adding Error Bars to a Bar Chart
# Error bars provide insight into the variability or uncertainty of data. They help to assess whether the differences between groups are meaningful or could be due to natural variation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create synthetic data
np.random.seed(42)

# Simulated heights for men's rowing (typically taller)
mens_rowing = pd.DataFrame({
    'Height': np.random.normal(loc=190, scale=5, size=100)  # Mean ~190 cm
})

# Simulated heights for men's gymnastics (typically shorter)
mens_gymnastics = pd.DataFrame({
    'Height': np.random.normal(loc=168, scale=6, size=100)  # Mean ~168 cm
})

# Plotting
fig, ax = plt.subplots()

# Bar for rowing: mean height with std deviation as error
ax.bar("Rowing", mens_rowing['Height'].mean(), yerr=mens_rowing['Height'].std())

# Bar for gymnastics: mean height with std deviation as error
ax.bar("Gymnastics", mens_gymnastics['Height'].mean(), yerr=mens_gymnastics['Height'].std())

# Label the y-axis
ax.set_ylabel("Height (cm)")

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define months
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# Create synthetic Seattle weather data
seattle_weather = pd.DataFrame({
    "MONTH": months,
    "MLY-TAVG-NORMAL": [40, 43, 47, 52, 58, 63, 67, 67, 62, 53, 46, 41],
    "MLY-TAVG-STDDEV": [4, 3, 3, 2, 2, 2, 2, 2, 2, 3, 3, 4]
})

# Create synthetic Austin weather data
austin_weather = pd.DataFrame({
    "MONTH": months,
    "MLY-TAVG-NORMAL": [50, 54, 61, 69, 76, 82, 85, 86, 80, 70, 60, 52],
    "MLY-TAVG-STDDEV": [3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 3, 3]
})

# Plotting
fig, ax = plt.subplots()

# Add Seattle temperature data in each month with error bars
ax.errorbar(seattle_weather['MONTH'],
            seattle_weather['MLY-TAVG-NORMAL'],
            seattle_weather['MLY-TAVG-STDDEV'],
            label='Seattle')

# Add Austin temperature data in each month with error bars
ax.errorbar(austin_weather['MONTH'],
            austin_weather['MLY-TAVG-NORMAL'],
            austin_weather['MLY-TAVG-STDDEV'],
            label='Austin')

# Set the y-axis label
ax.set_ylabel("Temperature (Fahrenheit)")

# Add a legend
ax.legend()

plt.show()

# %% [markdown]
# ## 📦 Visualizing Score Distributions with Boxplots
# Boxplots are a great way to summarize the distribution of a dataset. They show the median, interquartile range (IQR), and the range where most of the data lies. Any outliers that fall far outside the typical spread are shown as individual points.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create synthetic data
np.random.seed(42)

# Simulated heights for men's rowing (typically taller)
mens_rowing = pd.DataFrame({
    'Height': np.random.normal(loc=190, scale=5, size=100)  # mean 190 cm
})

# Simulated heights for men's gymnastics (typically shorter)
mens_gymnastics = pd.DataFrame({
    'Height': np.random.normal(loc=168, scale=6, size=100)  # mean 168 cm
})

# Plotting
fig, ax = plt.subplots()

# Boxplot of heights for both groups
ax.boxplot([mens_rowing['Height'], mens_gymnastics['Height']])

# Set x-axis labels
ax.set_xticklabels(["Rowing", "Gymnastics"])

# Set y-axis label
ax.set_ylabel("Height (cm)")

plt.show()

# %% [markdown]
# ## Simple Scatter Plot
# A scatter plot is used to visualize the relationship between two numeric variables. Each data point represents a single observation. The value of one variable is plotted on the x-axis, and the other is plotted on the y-axis. This makes it easy to observe trends, clusters, or potential correlations between the two variables.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create synthetic dataset
np.random.seed(1)
study_hours = np.random.uniform(1, 10, 100)
exam_scores = 5 * study_hours + np.random.normal(0, 5, 100)

students = pd.DataFrame({
    "study_hours": study_hours,
    "exam_score": exam_scores
})

# Plotting
fig, ax = plt.subplots()

# Add data: "study_hours" on x-axis, "exam_score" on y-axis
ax.scatter(students["study_hours"], students["exam_score"])

# Set the x-axis label to "Study Hours"
ax.set_xlabel("Study Hours")

# Set the y-axis label to "Final Exam Score"
ax.set_ylabel("Final Exam Score")

plt.show()

# %% [markdown]
# ## Encoding Age by Color
# Scatter plots are primarily used to visualize the relationship between two numeric variables. However, by using color as a third visual dimension, we can reveal additional information within the same two-dimensional space.
#
# For instance, in a dataset of students, we might want to understand how age correlates with other variables like study hours and final exam scores. In this exercise, we’ll create a scatter plot of study hours (on the x-axis) vs. final exam scores (on the y-axis), while using color to represent the age of each student.
#
# Using a colormap (such as Viridis), younger students can be displayed in darker shades, while older students appear in brighter yellow hues, helping us visually identify age-related trends or patterns within the data.

# %%
import pandas as pd

df = pd.read_csv("../Matplotlib/dataset/stockdata.csv")
fig, ax = plt.subplots()

# Add data: "co2", "relative_temp" as x-y, index as color
ax.scatter(df["close_price"], df["volume"], c=df.index)

# Set the x-axis label to "CO2 (ppm)"
ax.set_xlabel("Closing Price")

# Set the y-axis label to "Relative temperature (C)"
ax.set_ylabel("Volume")

plt.show()
